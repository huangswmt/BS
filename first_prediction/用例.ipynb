# %%
from first_predict import *

# %%
DPS = first_Predict_shop()
DPS.shop_name_clean()
DPS.frequancy_filter()
DPS.get_one()

# %%
DPS.prepare()

# %%
DPS.predict_one('ysl')
# Out:
# ['维多利亚秘密', '雷诺瓦', 'gucci', 'freak shake', 'sly']

# %%
s2 = 'adidas'
s1 = 'fila'
DPS.cheack_trans_flow(s1,s2)

# %%
s2 = ''
s1 = 'fila'
DPS.cheack_trans_flow(s1,s2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-086540d57a59> in <module>
#       1 s2 = ''
#       2 s1 = 'fila'
# ----> 3 DPS.cheack_trans_flow(s1,s2)
#
# ~/hsy/整理内容/first_prediction/first_predict.py in cheack_trans_flow(self, s1, s2)
#     225     def cheack_trans_flow(self,s1,s2=''):
#     226         if s2 =='':
# --> 227             look_up_table = DPS.dff_m[(DPS.dff_m['店铺名称'] ==s1)]
#     228         else:
#     229             look_up_table = self.dff_m[(self.dff_m['店铺名称'] ==s1) & (self.dff_m['shift_shop'] ==s2)]
#
# NameError: name 'DPS' is not defined

# %%
DPS.plot_mat_come(s2)

# %%
DPS.plot_mat_out(s2)
